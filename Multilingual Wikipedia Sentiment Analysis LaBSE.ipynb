# %%
from typing import Dict, Optional, List
import wikipediaapi
from transformers import AutoModel, AutoTokenizer
import pandas as pd
import numpy as np
from concurrent.futures import ThreadPoolExecutor
from functools import partial
import logging
import torch
from sklearn.metrics.pairwise import cosine_similarity

class WikiLaBSEAnalyzer:
    def __init__(self, user_agent: str):
        """
        Set up the Wikipedia LaBSE analyzer:
        - Initialize Wikipedia API connection
        - Select best available computational device
        - Load multilingual embedding model
        - Configure logging
        """
        self.wiki = wikipediaapi.Wikipedia(user_agent, 'en')
        
        # Choose the best available computational device
        if torch.cuda.is_available():
            device = torch.device("cuda")
        elif torch.backends.mps.is_available():
            device = torch.device("mps")
        else:
            device = torch.device("cpu")
            
        self.device = device
        
        # Load Language-agnostic BERT Sentence Embedding (LaBSE) model
        self.model = AutoModel.from_pretrained('setu4993/LaBSE').to(device)
        self.tokenizer = AutoTokenizer.from_pretrained('setu4993/LaBSE')
        
        # Supported language codes
        self.languages = ['en', 'pl', 'it', 'hu', 'de', 'nl', 'el', 'sv', 'ko', 'th', 'tl', 'ja', 'si', 'bn', 'hi', 'ms', 'he', 'tr']
        
        # Configure logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        self.logger = logging.getLogger(__name__)
        
        # Log the computational device in use
        device_name = "GPU" if device.type == "cuda" else "Apple Silicon" if device.type == "mps" else "CPU"
        self.logger.info(f"Using device: {device_name}")

    def fetch_article_texts(self, article_name: str) -> Dict[str, Optional[str]]:
        """
        Retrieve Wikipedia article content in multiple languages:
        - Starts with English article
        - Attempts to find translations for other supported languages
        - Returns dictionary of language codes and their article texts
        
        Handles potential errors:
        - Logs if an article is not found
        - Returns None for unavailable translations
        """
        texts = {}
        
        # Retrieve English article
        page = self.wiki.page(article_name)
        if not page.exists():
            self.logger.error(f"en article '{article_name}' not found")
            texts['en'] = None
        else:
            texts['en'] = page.text
            self.logger.info(f"Found en article: {article_name}")
        
        # Retrieve translations for other languages
        for lang in self.languages[1:]:  # Skip English
            try:
                lang_page = page.langlinks.get(lang)
                if lang_page:
                    texts[lang] = lang_page.text
                    self.logger.info(f"Found {lang} article: {lang_page.title}")
                else:
                    self.logger.warning(f"No {lang} translation available")
                    texts[lang] = None
            except Exception as e:
                self.logger.error(f"Error fetching {lang} article: {str(e)}")
                texts[lang] = None
                
        return texts

    def get_embedding(self, text: str, chunk_size: int = 512) -> Optional[np.ndarray]:
        """
        Generate embedding for a text chunk:
        - Tokenizes input text
        - Uses LaBSE model to create language-agnostic embeddings
        - Returns embedding vector or None if processing fails
        """
        try:
            if not text.strip():
                return None
                
            # Tokenize and prepare input
            inputs = self.tokenizer(text[:chunk_size], return_tensors="pt", 
                                  padding=True, truncation=True, max_length=chunk_size)
            inputs = {k: v.to(self.device) for k, v in inputs.items()}
            
            # Generate embeddings
            with torch.no_grad():
                outputs = self.model(**inputs)
                embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()  # Use [CLS] token embedding
                
            return embeddings[0]  # Return the embedding vector
            
        except Exception as e:
            self.logger.error(f"Error getting embedding: {str(e)}")
            return None

    def process_chunks(self, chunks: List[str], chunk_size: int) -> List[np.ndarray]:
        """
        Process text chunks and extract valid embeddings:
        - Iterates through text chunks
        - Generates embedding for each chunk
        - Filters out any failed embedding generations
        """
        embeddings = []
        for chunk in chunks:
            embedding = self.get_embedding(chunk, chunk_size)
            if embedding is not None:  # Only append if we got a valid embedding
                embeddings.append(embedding)
        return embeddings

    def compute_similarity_metrics(self, text: str, chunk_size: int = 512) -> Optional[Dict[str, float]]:
        """
        Compute text chunk similarity metrics:
        - Splits text into manageable chunks
        - Generates embeddings for each chunk
        - Calculates pairwise cosine similarities
        - Computes statistical measures of chunk similarities
        """
        if not text:
            return None
            
        # Split text into chunks
        chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
        
        # Get embeddings for all chunks
        embeddings = self.process_chunks(chunks, chunk_size)
            
        if not embeddings:
            return None
            
        # Convert to numpy array
        embeddings = np.array(embeddings)
        
        # Compute pairwise similarities
        similarities = cosine_similarity(embeddings)
        
        # Get upper triangle indices for unique comparisons
        upper_tri_indices = np.triu_indices_from(similarities, k=1)
        
        # If we have valid similarities to compare
        if len(similarities[upper_tri_indices]) > 0:
            return {
                'average_score': float(np.mean(similarities[upper_tri_indices])),
                'median_score': float(np.median(similarities[upper_tri_indices])),
                'standard_deviation': float(np.std(similarities[upper_tri_indices]))
            }
        else:
            # If we only have one chunk or no valid comparisons
            return {
                'average_score': 1.0,  # Perfect similarity with itself
                'median_score': 1.0,
                'standard_deviation': 0.0
            }

    def create_report(self, article_name: str, results: Dict[str, Optional[Dict[str, float]]], output_file: str = 'sentiment_statistics_labse.csv') -> pd.DataFrame:
        """
        Generate comprehensive analysis report:
        - Creates structured data from analysis results
        - Handles both successful and failed analyses
        - Manages CSV file operations:
          * Creates new file if needed
          * Updates existing file
          * Prevents duplicate entries
        
        Ensures clean and consistent data representation
        """
        report_data = []
        
        for language, data in results.items():
            if data:
                report_data.append({
                    'Article_Title': article_name,
                    'Language': language,
                    'Mean_Sentiment_Score': f"{data['average_score']:.3f}",
                    'Median_Sentiment_Score': f"{data['median_score']:.3f}",
                    'Standard_Deviation': f"{data['standard_deviation']:.3f}"
                })
            else:
                report_data.append({
                    'Article_Title': article_name,
                    'Language': language,
                    'Mean_Sentiment_Score': 'NA',
                    'Median_Sentiment_Score': 'NA',
                    'Standard_Deviation': 'NA'
                })
                
        stats_df = pd.DataFrame(report_data)
        
        try:
            existing_df = pd.read_csv(output_file)
            # Remove any existing entries for this article
            existing_df = existing_df[existing_df.Article_Title != article_name]
            updated_df = pd.concat([existing_df, stats_df], ignore_index=True)
        except FileNotFoundError:
            updated_df = stats_df
            
        updated_df.to_csv(output_file, index=False)
        return updated_df

    def analyze_article(self, article_name: str, chunk_size: int = 512) -> pd.DataFrame:
        """
        Main method to analyze a Wikipedia article:
        - Retrieves article texts in multiple languages
        - Performs embedding and similarity analysis
        - Generates comprehensive report
        
        Single entry point for full multilingual embedding analysis
        """
        self.logger.info(f"Starting analysis of article: {article_name}")
        
        # Fetch article texts in different languages
        texts = self.fetch_article_texts(article_name)
        
        # Analyze text embeddings for each language
        results = {}
        for lang, text in texts.items():
            self.logger.info(f"Analyzing text for language: {lang}")
            results[lang] = self.compute_similarity_metrics(text, chunk_size) if text else None
            
        # Create and save report
        report = self.create_report(article_name, results)
        self.logger.info("Analysis completed successfully")
        return report

# Usage example
if __name__ == "__main__":
    analyzer = WikiLaBSEAnalyzer('WikiLaBSEAnalysis/1.0 (username@email.com)')
    
    presidents = ['Joe Biden', 'Donald Trump', 'Barack Obama', 'George W. Bush', 'Bill Clinton', 'George H. W. Bush', 'Ronald Reagan', 
                  'Jimmy Carter', 'Gerald Ford', 'Richard Nixon', 'Lyndon B. Johnson', 'John F. Kennedy', 'Dwight D. Eisenhower', 'Harry S. Truman', 
                  'Franklin D. Roosevelt', 'Herbert Hoover', 'Calvin Coolidge', 'Warren G. Harding', 'Woodrow Wilson', 'William Howard Taft', 
                  'Theodore Roosevelt', 'William McKinley', 'Grover Cleveland', 'Benjamin Harrison', 'Chester A. Arthur', 'James A. Garfield', 
                  'Rutherford B. Hayes', 'Ulysses S. Grant', 'Andrew Johnson', 'Abraham Lincoln', 'James Buchanan', 'Franklin Pierce', 
                  'Millard Fillmore', 'Zachary Taylor', 'James K. Polk', 'John Tyler', 'William Henry Harrison', 'Martin Van Buren', 'Andrew Jackson', 
                  'John Quincy Adams', 'James Monroe', 'James Madison', 'Thomas Jefferson', 'John Adams', 'George Washington']
    for president in presidents:
        report = analyzer.analyze_article(president)
    
    print(report)
# Out:
# 2024-11-22 22:33:29,998 - INFO - Using device: CPU
# 2024-11-22 22:33:29,998 - INFO - Starting analysis of article: Joe Biden
# 2024-11-22 22:33:29,998 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Joe Biden&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 22:33:30,555 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:31,967 - INFO - Found en article: Joe Biden
# 2024-11-22 22:33:31,967 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=Joe Biden&lllimit=500&llprop=url
# 2024-11-22 22:33:32,101 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:32,280 - INFO - Found pl article: Joe Biden
# 2024-11-22 22:33:32,280 - INFO - Request URL: https://it.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:32,488 - INFO - Found it article: Joe Biden
# 2024-11-22 22:33:32,488 - INFO - Request URL: https://hu.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:32,724 - INFO - Found hu article: Joe Biden
# 2024-11-22 22:33:32,724 - INFO - Request URL: https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:32,988 - INFO - Found de article: Joe Biden
# 2024-11-22 22:33:32,988 - INFO - Request URL: https://nl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:33,188 - INFO - Found nl article: Joe Biden
# 2024-11-22 22:33:33,188 - INFO - Request URL: https://el.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Τζο Μπάιντεν&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:33,523 - INFO - Found el article: Τζο Μπάιντεν
# 2024-11-22 22:33:33,523 - INFO - Request URL: https://sv.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:33,726 - INFO - Found sv article: Joe Biden
# 2024-11-22 22:33:33,738 - INFO - Request URL: https://ko.wikipedia.org/w/api.php?action=query&prop=extracts&titles=조 바이든&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:33,870 - INFO - Found ko article: 조 바이든
# 2024-11-22 22:33:33,870 - INFO - Request URL: https://th.wikipedia.org/w/api.php?action=query&prop=extracts&titles=โจ ไบเดิน&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:34,099 - INFO - Found th article: โจ ไบเดิน
# 2024-11-22 22:33:34,099 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:34,231 - INFO - Found tl article: Joe Biden
# 2024-11-22 22:33:34,231 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ジョー・バイデン&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:34,582 - INFO - Found ja article: ジョー・バイデン
# 2024-11-22 22:33:34,582 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ජෝ බයිඩන්&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:34,726 - INFO - Found si article: ජෝ බයිඩන්
# 2024-11-22 22:33:34,726 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=জো বাইডেন&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:35,003 - INFO - Found bn article: জো বাইডেন
# 2024-11-22 22:33:35,003 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=जो बाइडन&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:35,135 - INFO - Found hi article: जो बाइडन
# 2024-11-22 22:33:35,147 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:35,363 - INFO - Found ms article: Joe Biden
# 2024-11-22 22:33:35,363 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ג'ו ביידן&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:35,808 - INFO - Found he article: ג'ו ביידן
# 2024-11-22 22:33:35,808 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Joe Biden&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:33:36,039 - INFO - Found tr article: Joe Biden
# 2024-11-22 22:33:36,039 - INFO - Analyzing text for language: en
# 2024-11-22 22:33:59,149 - INFO - Analyzing text for language: pl
# 2024-11-22 22:34:08,745 - INFO - Analyzing text for language: it
# 2024-11-22 22:34:21,365 - INFO - Analyzing text for language: hu
# 2024-11-22 22:34:30,694 - INFO - Analyzing text for language: de
# 2024-11-22 22:34:47,755 - INFO - Analyzing text for language: nl
# 2024-11-22 22:34:54,376 - INFO - Analyzing text for language: el
# 2024-11-22 22:35:08,880 - INFO - Analyzing text for language: sv
# 2024-11-22 22:35:16,551 - INFO - Analyzing text for language: ko
# 2024-11-22 22:35:19,103 - INFO - Analyzing text for language: th
# 2024-11-22 22:35:27,539 - INFO - Analyzing text for language: tl
# 2024-11-22 22:35:28,242 - INFO - Analyzing text for language: ja
# 2024-11-22 22:36:27,069 - INFO - Analyzing text for language: si
# 2024-11-22 22:36:27,376 - INFO - Analyzing text for language: bn
# 2024-11-22 22:36:35,372 - INFO - Analyzing text for language: hi
# 2024-11-22 22:36:36,968 - INFO - Analyzing text for language: ms
# 2024-11-22 22:36:49,540 - INFO - Analyzing text for language: he
# 2024-11-22 22:37:22,390 - INFO - Analyzing text for language: tr
# 2024-11-22 22:37:30,484 - INFO - Analysis completed successfully
# 2024-11-22 22:37:30,484 - INFO - Starting analysis of article: Herbert Hoover
# 2024-11-22 22:37:30,484 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Herbert Hoover&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 22:37:30,819 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:31,258 - INFO - Found en article: Herbert Hoover
# 2024-11-22 22:37:31,258 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=Herbert Hoover&lllimit=500&llprop=url
# 2024-11-22 22:37:31,412 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:31,610 - INFO - Found pl article: Herbert Hoover
# 2024-11-22 22:37:31,619 - INFO - Request URL: https://it.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:31,783 - INFO - Found it article: Herbert Hoover
# 2024-11-22 22:37:31,783 - INFO - Request URL: https://hu.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:31,946 - INFO - Found hu article: Herbert Hoover
# 2024-11-22 22:37:31,946 - INFO - Request URL: https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:32,228 - INFO - Found de article: Herbert Hoover
# 2024-11-22 22:37:32,228 - INFO - Request URL: https://nl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:32,429 - INFO - Found nl article: Herbert Hoover
# 2024-11-22 22:37:32,429 - INFO - Request URL: https://el.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Χέρμπερτ Χούβερ&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:32,647 - INFO - Found el article: Χέρμπερτ Χούβερ
# 2024-11-22 22:37:32,647 - INFO - Request URL: https://sv.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:32,811 - INFO - Found sv article: Herbert Hoover
# 2024-11-22 22:37:32,811 - INFO - Request URL: https://ko.wikipedia.org/w/api.php?action=query&prop=extracts&titles=허버트 후버&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:33,081 - INFO - Found ko article: 허버트 후버
# 2024-11-22 22:37:33,081 - INFO - Request URL: https://th.wikipedia.org/w/api.php?action=query&prop=extracts&titles=เฮอร์เบิร์ต ฮูเวอร์&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:33,296 - INFO - Found th article: เฮอร์เบิร์ต ฮูเวอร์
# 2024-11-22 22:37:33,296 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:33,442 - INFO - Found tl article: Pangulo ng Estados Unidos
# 2024-11-22 22:37:33,451 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ハーバート・フーヴァー&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:33,651 - INFO - Found ja article: ハーバート・フーヴァー
# 2024-11-22 22:37:33,651 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=හර්බට් හූවර්&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:33,788 - INFO - Found si article: හර්බට් හූවර්
# 2024-11-22 22:37:33,788 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=হার্বার্ট হুভার&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:33,946 - INFO - Found bn article: হার্বার্ট হুভার
# 2024-11-22 22:37:33,955 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=हर्बर्ट क्लार्क हूवर&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:34,112 - INFO - Found hi article: हर्बर्ट क्लार्क हूवर
# 2024-11-22 22:37:34,112 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:34,271 - INFO - Found ms article: Herbert Hoover
# 2024-11-22 22:37:34,280 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=הרברט הובר&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:37:34,618 - INFO - Found he article: הרברט הובר
# 2024-11-22 22:37:34,618 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Herbert C. Hoover&explaintext=1&exsectionformat=wiki
# 2024-11-22 22
explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:10,438 - INFO - Found tl article: Pangulo ng Estados Unidos
# 2024-11-22 22:39:10,438 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=カルビン・クーリッジ&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:10,648 - INFO - Found ja article: カルビン・クーリッジ
# 2024-11-22 22:39:10,648 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=කැල්වින් කූලිජ්&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:10,813 - INFO - Found si article: කැල්වින් කූලිජ්
# 2024-11-22 22:39:10,813 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ক্যালভিন কুলিজ&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:10,963 - INFO - Found bn article: ক্যালভিন কুলিজ
# 2024-11-22 22:39:10,963 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=कॉल्विन कूलिज&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:11,161 - INFO - Found hi article: कॉल्विन कूलिज
# 2024-11-22 22:39:11,163 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Calvin Coolidge&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:11,288 - INFO - Found ms article: Calvin Coolidge
# 2024-11-22 22:39:11,288 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=קלווין קולידג'&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:11,691 - INFO - Found he article: קלווין קולידג'
# 2024-11-22 22:39:11,691 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Calvin Coolidge&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:39:11,911 - INFO - Found tr article: Calvin Coolidge
# 2024-11-22 22:39:11,911 - INFO - Analyzing text for language: en
# 2024-11-22 22:39:25,373 - INFO - Analyzing text for language: pl
# 2024-11-22 22:39:28,175 - INFO - Analyzing text for language: it
# 2024-11-22 22:39:30,363 - INFO - Analyzing text for language: hu
# 2024-11-22 22:39:31,091 - INFO - Analyzing text for language: de
# 2024-11-22 22:39:46,696 - INFO - Analyzing text for language: nl
# 2024-11-22 22:39:48,710 - INFO - Analyzing text for language: el
# 2024-11-22 22:39:51,541 - INFO - Analyzing text for language: sv
# 2024-11-22 22:39:53,322 - INFO - Analyzing text for language: ko
# 2024-11-22 22:39:55,849 - INFO - Analyzing text for language: th
# 2024-11-22 22:39:58,095 - INFO - Analyzing text for language: tl
# 2024-11-22 22:39:58,554 - INFO - Analyzing text for language: ja
# 2024-11-22 22:40:01,259 - INFO - Analyzing text for language: si
# 2024-11-22 22:40:01,307 - INFO - Analyzing text for language: bn
# 2024-11-22 22:40:01,791 - INFO - Analyzing text for language: hi
# 2024-11-22 22:40:01,845 - INFO - Analyzing text for language: ms
# 2024-11-22 22:40:02,583 - INFO - Analyzing text for language: he
# 2024-11-22 22:40:27,549 - INFO - Analyzing text for language: tr
# 2024-11-22 22:40:27,779 - INFO - Analysis completed successfully
# 2024-11-22 22:40:27,779 - INFO - Starting analysis of article: Warren G. Harding
# 2024-11-22 22:40:27,779 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Warren G. Harding&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 22:40:28,072 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Warren G. Harding&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:40:28,291 - INFO - Found en article: Warren G. Harding
# 2024-11-22 22:40:28,291 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=Warren G. Harding&lllimit=500&llprop=url
# 2024-11-22 22:40:28,402 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Warren Harding&explaintext=1&exsectionformat=wiki
# 2024-11-22 22
explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:53,717 - INFO - Found ja article: ウッドロウ・ウィルソン
# 2024-11-22 22:41:53,725 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=වුඩ්රෝ විල්සන්&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:53,928 - INFO - Found si article: වුඩ්රෝ විල්සන්
# 2024-11-22 22:41:53,928 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=উড্রো উইলসন&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:54,085 - INFO - Found bn article: উড্রো উইলসন
# 2024-11-22 22:41:54,085 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=वुडरो विल्सन&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:54,327 - INFO - Found hi article: वुडरो विल्सन
# 2024-11-22 22:41:54,327 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Woodrow Wilson&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:54,468 - INFO - Found ms article: Woodrow Wilson
# 2024-11-22 22:41:54,468 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=וודרו וילסון&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:54,837 - INFO - Found he article: וודרו וילסון
# 2024-11-22 22:41:54,837 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Woodrow Wilson&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:41:54,962 - INFO - Found tr article: Woodrow Wilson
# 2024-11-22 22:41:54,962 - INFO - Analyzing text for language: en
# 2024-11-22 22:42:16,685 - INFO - Analyzing text for language: pl
# 2024-11-22 22:42:23,437 - INFO - Analyzing text for language: it
# 2024-11-22 22:42:31,349 - INFO - Analyzing text for language: hu
# 2024-11-22 22:42:32,985 - INFO - Analyzing text for language: de
# 2024-11-22 22:42:42,142 - INFO - Analyzing text for language: nl
# 2024-11-22 22:42:44,793 - INFO - Analyzing text for language: el
# 2024-11-22 22:42:45,546 - INFO - Analyzing text for language: sv
# 2024-11-22 22:42:48,293 - INFO - Analyzing text for language: ko
# 2024-11-22 22:42:54,880 - INFO - Analyzing text for language: th
# 2024-11-22 22:42:56,498 - INFO - Analyzing text for language: tl
# 2024-11-22 22:42:56,732 - INFO - Analyzing text for language: ja
# 2024-11-22 22:43:03,749 - INFO - Analyzing text for language: si
# 2024-11-22 22:43:05,034 - INFO - Analyzing text for language: bn
# 2024-11-22 22:43:05,167 - INFO - Analyzing text for language: hi
# 2024-11-22 22:43:11,896 - INFO - Analyzing text for language: ms
# 2024-11-22 22:43:13,174 - INFO - Analyzing text for language: he
# 2024-11-22 22:43:34,997 - INFO - Analyzing text for language: tr
# 2024-11-22 22:43:36,155 - INFO - Analysis completed successfully
# 2024-11-22 22:43:36,155 - INFO - Starting analysis of article: William Howard Taft
# 2024-11-22 22:43:36,155 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=William Howard Taft&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 22:43:36,416 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William Howard Taft&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:43:36,885 - INFO - Found en article: William Howard Taft
# 2024-11-22 22:43:36,885 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=William Howard Taft&lllimit=500&llprop=url
# 2024-11-22 22:43:37,052 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William Taft&explaintext=1&exsectionformat=wiki
# 2024-11-22 22
explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:00,399 - INFO - Found ko article: 시어도어 루스벨트
# 2024-11-22 22:45:00,399 - INFO - Request URL: https://th.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ทีโอดอร์ โรเซอเวลต์&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:00,586 - INFO - Found th article: ทีโอดอร์ โรเซอเวลต์
# 2024-11-22 22:45:00,586 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Theodore Roosevelt&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:00,763 - INFO - Found tl article: Theodore Roosevelt
# 2024-11-22 22:45:00,763 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=セオドア・ルーズベルト&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:01,024 - INFO - Found ja article: セオドア・ルーズベルト
# 2024-11-22 22:45:01,032 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=තියඩෝර් රෝසවෙල්&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:01,193 - INFO - Found si article: තියඩෝර් රෝසවෙල්
# 2024-11-22 22:45:01,193 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=থিওডোর রুজভেল্ট&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:01,355 - INFO - Found bn article: থিওডোর রুজভেল্ট
# 2024-11-22 22:45:01,355 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=थियोडोर रूज़वेल्ट&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:01,519 - INFO - Found hi article: थियोडोर रूज़वेल्ट
# 2024-11-22 22:45:01,524 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Theodore Roosevelt&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:01,670 - INFO - Found ms article: Theodore Roosevelt
# 2024-11-22 22:45:01,670 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=תאודור רוזוולט&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:02,041 - INFO - Found he article: תאודור רוזוולט
# 2024-11-22 22:45:02,042 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Theodore Roosevelt&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:45:02,196 - INFO - Found tr article: Theodore Roosevelt
# 2024-11-22 22:45:02,196 - INFO - Analyzing text for language: en
# 2024-11-22 22:45:30,019 - INFO - Analyzing text for language: pl
# 2024-11-22 22:45:34,157 - INFO - Analyzing text for language: it
# 2024-11-22 22:45:39,901 - INFO - Analyzing text for language: hu
# 2024-11-22 22:45:46,763 - INFO - Analyzing text for language: de
# 2024-11-22 22:45:55,649 - INFO - Analyzing text for language: nl
# 2024-11-22 22:45:58,180 - INFO - Analyzing text for language: el
# 2024-11-22 22:45:58,933 - INFO - Analyzing text for language: sv
# 2024-11-22 22:46:01,062 - INFO - Analyzing text for language: ko
# 2024-11-22 22:46:08,743 - INFO - Analyzing text for language: th
# 2024-11-22 22:46:12,320 - INFO - Analyzing text for language: tl
# 2024-11-22 22:46:12,576 - INFO - Analyzing text for language: ja
# 2024-11-22 22:46:22,595 - INFO - Analyzing text for language: si
# 2024-11-22 22:46:22,643 - INFO - Analyzing text for language: bn
# 2024-11-22 22:46:22,795 - INFO - Analyzing text for language: hi
# 2024-11-22 22:46:22,851 - INFO - Analyzing text for language: ms
# 2024-11-22 22:46:23,784 - INFO - Analyzing text for language: he
# 2024-11-22 22:46:41,815 - INFO - Analyzing text for language: tr
# 2024-11-22 22:46:43,308 - INFO - Analysis completed successfully
# 2024-11-22 22:46:43,308 - INFO - Starting analysis of article: William McKinley
# 2024-11-22 22:46:43,308 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=William McKinley&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 22:46:43,540 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:43,743 - INFO - Found en article: William McKinley
# 2024-11-22 22:46:43,743 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=William McKinley&lllimit=500&llprop=url
# 2024-11-22 22:46:43,843 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:43,999 - INFO - Found pl article: William McKinley
# 2024-11-22 22:46:43,999 - INFO - Request URL: https://it.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:44,154 - INFO - Found it article: William McKinley
# 2024-11-22 22:46:44,154 - INFO - Request URL: https://hu.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:44,281 - INFO - Found hu article: William McKinley
# 2024-11-22 22:46:44,281 - INFO - Request URL: https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:44,471 - INFO - Found de article: William McKinley
# 2024-11-22 22:46:44,473 - INFO - Request URL: https://nl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:44,610 - INFO - Found nl article: William McKinley
# 2024-11-22 22:46:44,610 - INFO - Request URL: https://el.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ουίλλιαμ ΜακΚίνλεϊ&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:44,768 - INFO - Found el article: Ουίλλιαμ ΜακΚίνλεϊ
# 2024-11-22 22:46:44,768 - INFO - Request URL: https://sv.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:44,920 - INFO - Found sv article: William McKinley
# 2024-11-22 22:46:44,920 - INFO - Request URL: https://ko.wikipedia.org/w/api.php?action=query&prop=extracts&titles=윌리엄 매킨리&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:45,111 - INFO - Found ko article: 윌리엄 매킨리
# 2024-11-22 22:46:45,111 - INFO - Request URL: https://th.wikipedia.org/w/api.php?action=query&prop=extracts&titles=วิลเลียม แมกคินลีย์&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:45,266 - INFO - Found th article: วิลเลียม แมกคินลีย์
# 2024-11-22 22:46:45,266 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:45,402 - INFO - Found tl article: William McKinley
# 2024-11-22 22:46:45,412 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ウィリアム・マッキンリー&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:45,612 - INFO - Found ja article: ウィリアム・マッキンリー
# 2024-11-22 22:46:45,612 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=විලියම් මැක්කින්ලි&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:45,776 - INFO - Found si article: විලියම් මැක්කින්ලි
# 2024-11-22 22:46:45,776 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=উইলিয়াম ম্যাকিনলি&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:45,922 - INFO - Found bn article: উইলিয়াম ম্যাকিনলি
# 2024-11-22 22:46:45,922 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=विलियम मैकिनले&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:46,072 - INFO - Found hi article: विलियम मैकिनले
# 2024-11-22 22:46:46,072 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:46,232 - INFO - Found ms article: William McKinley
# 2024-11-22 22:46:46,232 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ויליאם מקינלי&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:46,606 - INFO - Found he article: ויליאם מקינלי
# 2024-11-22 22:46:46,606 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=William McKinley&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:46:46,749 - INFO - Found tr article: William McKinley
# 2024-11-22 22:46:46,749 - INFO - Analyzing text for language: en
# 2024-11-22 22:47:06,904 - INFO - Analyzing text for language: pl
# 2024-11-22 22:47:10,095 - INFO - Analyzing text for language: it
# 2024-11-22 22:47:14,350 - INFO - Analyzing text for language: hu
# 2024-11-22 22:47:17,272 - INFO - Analyzing text for language: de
# 2024-11-22 22:47:20,948 - INFO - Analyzing text for language: nl
# 2024-11-22 22:47:22,022 - INFO - Analyzing text for language: el
# 2024-11-22 22:47:22,833 - INFO - Analyzing text for language: sv
# 2024-11-22 22:47:23,653 - INFO - Analyzing text for language: ko
# 2024-11-22 22:47:27,099 - INFO - Analyzing text for language: th
# 2024-11-22 22:47:27,768 - INFO - Analyzing text for language: tl
# 2024-11-22 22:47:28,235 - INFO - Analyzing text for language: ja
# 2024-11-22 22:47:32,853 - INFO - Analyzing text for language: si
# 2024-11-22 22:47:32,907 - INFO - Analyzing text for language: bn
# 2024-11-22 22:47:33,006 - INFO - Analyzing text for language: hi
# 2024-11-22 22:47:33,069 - INFO - Analyzing text for language: ms
# 2024-11-22 22:47:33,736 - INFO - Analyzing text for language: he
# 2024-11-22 22:47:54,794 - INFO - Analyzing text for language: tr
# 2024-11-22 22:47:55,844 - INFO - Analysis completed successfully
# 2024-11-22 22:47:55,844 - INFO - Starting analysis of article: Grover Cleveland
# 2024-11-22 22:47:55,852 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=Grover Cleveland&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 22:47:56,082 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Grover Cleveland&explaintext=1&exsectionformat=wiki
# 2024-11-22 22:47:56,294 - INFO - Found en article: Grover Cleveland
# ...
# 2024-11-22 23:19:16,694 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Thomas Jefferson&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:16,838 - INFO - Found tl article: Pangulo ng Estados Unidos
# 2024-11-22 23:19:16,838 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=トーマス・ジェファーソン&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:17,151 - INFO - Found ja article: トーマス・ジェファーソン
# 2024-11-22 23:19:17,151 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=තෝමස් ජෙෆර්සන්&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:17,287 - INFO - Found si article: තෝමස් ජෙෆර්සන්
# 2024-11-22 23:19:17,287 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=টমাস জেফারসন&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:17,415 - INFO - Found bn article: টমাস জেফারসন
# 2024-11-22 23:19:17,415 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=थॉमस जेफ़र्सन&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:17,567 - INFO - Found hi article: थॉमस जेफ़र्सन
# 2024-11-22 23:19:17,567 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Thomas Jefferson&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:17,711 - INFO - Found ms article: Thomas Jefferson
# 2024-11-22 23:19:17,711 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=תומאס ג'פרסון&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:18,120 - INFO - Found he article: תומאס ג'פרסון
# 2024-11-22 23:19:18,120 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Thomas Jefferson&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:19:18,385 - INFO - Found tr article: Thomas Jefferson
# 2024-11-22 23:19:18,385 - INFO - Analyzing text for language: en
# 2024-11-22 23:19:47,341 - INFO - Analyzing text for language: pl
# 2024-11-22 23:19:52,968 - INFO - Analyzing text for language: it
# 2024-11-22 23:20:11,733 - INFO - Analyzing text for language: hu
# 2024-11-22 23:20:16,665 - INFO - Analyzing text for language: de
# 2024-11-22 23:20:33,129 - INFO - Analyzing text for language: nl
# 2024-11-22 23:20:37,769 - INFO - Analyzing text for language: el
# 2024-11-22 23:20:38,138 - INFO - Analyzing text for language: sv
# 2024-11-22 23:20:42,062 - INFO - Analyzing text for language: ko
# 2024-11-22 23:21:04,637 - INFO - Analyzing text for language: th
# 2024-11-22 23:21:05,077 - INFO - Analyzing text for language: tl
# 2024-11-22 23:21:05,509 - INFO - Analyzing text for language: ja
# 2024-11-22 23:21:30,694 - INFO - Analyzing text for language: si
# 2024-11-22 23:21:31,423 - INFO - Analyzing text for language: bn
# 2024-11-22 23:21:32,874 - INFO - Analyzing text for language: hi
# 2024-11-22 23:21:33,314 - INFO - Analyzing text for language: ms
# 2024-11-22 23:21:34,211 - INFO - Analyzing text for language: he
# 2024-11-22 23:21:55,656 - INFO - Analyzing text for language: tr
# 2024-11-22 23:22:00,144 - INFO - Analysis completed successfully
# 2024-11-22 23:22:00,144 - INFO - Starting analysis of article: John Adams
# 2024-11-22 23:22:00,144 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=John Adams&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 23:22:00,473 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:00,691 - INFO - Found en article: John Adams
# 2024-11-22 23:22:00,691 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=John Adams&lllimit=500&llprop=url
# 2024-11-22 23:22:00,851 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:01,029 - INFO - Found pl article: John Adams
# 2024-11-22 23:22:01,029 - INFO - Request URL: https://it.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:01,238 - INFO - Found it article: John Adams
# 2024-11-22 23:22:01,238 - INFO - Request URL: https://hu.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams (amerikai elnök)&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:01,423 - INFO - Found hu article: John Adams (amerikai elnök)
# 2024-11-22 23:22:01,423 - INFO - Request URL: https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:01,694 - INFO - Found de article: John Adams
# 2024-11-22 23:22:01,694 - INFO - Request URL: https://nl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams (politicus)&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:01,831 - INFO - Found nl article: John Adams (politicus)
# 2024-11-22 23:22:01,831 - INFO - Request URL: https://el.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Τζον Άνταμς&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:01,959 - INFO - Found el article: Τζον Άνταμς
# 2024-11-22 23:22:01,967 - INFO - Request URL: https://sv.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:02,112 - INFO - Found sv article: John Adams
# 2024-11-22 23:22:02,120 - INFO - Request URL: https://ko.wikipedia.org/w/api.php?action=query&prop=extracts&titles=존 애덤스&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:02,299 - INFO - Found ko article: 존 애덤스
# 2024-11-22 23:22:02,305 - INFO - Request URL: https://th.wikipedia.org/w/api.php?action=query&prop=extracts&titles=จอห์น แอดัมส์&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:02,490 - INFO - Found th article: จอห์น แอดัมส์
# 2024-11-22 23:22:02,490 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:02,651 - INFO - Found tl article: John Adams
# 2024-11-22 23:22:02,651 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ジョン・アダムズ&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:02,948 - INFO - Found ja article: ジョン・アダムズ
# 2024-11-22 23:22:02,948 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ජෝන් ඇඩම්ස්&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:03,310 - INFO - Found si article: ජෝන් ඇඩම්ස්
# 2024-11-22 23:22:03,310 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=জন অ্যাডামস&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:03,455 - INFO - Found bn article: জন অ্যাডামস
# 2024-11-22 23:22:03,463 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=जॉन ऐडम्स&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:03,664 - INFO - Found hi article: जॉन ऐडम्स
# 2024-11-22 23:22:03,664 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:03,834 - INFO - Found ms article: John Adams
# 2024-11-22 23:22:03,835 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ג'ון אדמס&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:04,196 - INFO - Found he article: ג'ון אדמס
# 2024-11-22 23:22:04,197 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=John Adams&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:22:04,382 - INFO - Found tr article: John Adams
# 2024-11-22 23:22:04,389 - INFO - Analyzing text for language: en
# 2024-11-22 23:22:27,739 - INFO - Analyzing text for language: pl
# 2024-11-22 23:22:31,160 - INFO - Analyzing text for language: it
# 2024-11-22 23:22:35,095 - INFO - Analyzing text for language: hu
# 2024-11-22 23:22:36,963 - INFO - Analyzing text for language: de
# 2024-11-22 23:23:04,563 - INFO - Analyzing text for language: nl
# 2024-11-22 23:23:06,703 - INFO - Analyzing text for language: el
# 2024-11-22 23:23:07,031 - INFO - Analyzing text for language: sv
# 2024-11-22 23:23:08,849 - INFO - Analyzing text for language: ko
# 2024-11-22 23:23:10,412 - INFO - Analyzing text for language: th
# 2024-11-22 23:23:11,910 - INFO - Analyzing text for language: tl
# 2024-11-22 23:23:12,912 - INFO - Analyzing text for language: ja
# 2024-11-22 23:23:30,015 - INFO - Analyzing text for language: si
# 2024-11-22 23:23:45,528 - INFO - Analyzing text for language: bn
# 2024-11-22 23:23:45,695 - INFO - Analyzing text for language: hi
# 2024-11-22 23:23:46,728 - INFO - Analyzing text for language: ms
# 2024-11-22 23:23:48,491 - INFO - Analyzing text for language: he
# 2024-11-22 23:23:59,702 - INFO - Analyzing text for language: tr
# 2024-11-22 23:24:01,544 - INFO - Analysis completed successfully
# 2024-11-22 23:24:01,544 - INFO - Starting analysis of article: George Washington
# 2024-11-22 23:24:01,544 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=info&titles=George Washington&inprop=protection|talkid|watched|watchers|visitingwatchers|notificationtimestamp|subjectid|url|readable|preload|displaytitle
# 2024-11-22 23:24:02,336 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:02,542 - INFO - Found en article: George Washington
# 2024-11-22 23:24:02,542 - INFO - Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=langlinks&titles=George Washington&lllimit=500&llprop=url
# 2024-11-22 23:24:02,695 - INFO - Request URL: https://pl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:02,864 - INFO - Found pl article: George Washington
# 2024-11-22 23:24:02,864 - INFO - Request URL: https://it.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:03,024 - INFO - Found it article: George Washington
# 2024-11-22 23:24:03,024 - INFO - Request URL: https://hu.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:03,286 - INFO - Found hu article: George Washington
# 2024-11-22 23:24:03,286 - INFO - Request URL: https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:03,583 - INFO - Found de article: George Washington
# 2024-11-22 23:24:03,583 - INFO - Request URL: https://nl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:03,770 - INFO - Found nl article: George Washington
# 2024-11-22 23:24:03,776 - INFO - Request URL: https://el.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Τζορτζ Ουάσινγκτον&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:04,001 - INFO - Found el article: Τζορτζ Ουάσινγκτον
# 2024-11-22 23:24:04,001 - INFO - Request URL: https://sv.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:04,154 - INFO - Found sv article: George Washington
# 2024-11-22 23:24:04,162 - INFO - Request URL: https://ko.wikipedia.org/w/api.php?action=query&prop=extracts&titles=조지 워싱턴&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:04,413 - INFO - Found ko article: 조지 워싱턴
# 2024-11-22 23:24:04,413 - INFO - Request URL: https://th.wikipedia.org/w/api.php?action=query&prop=extracts&titles=จอร์จ วอชิงตัน&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:04,744 - INFO - Found th article: จอร์จ วอชิงตัน
# 2024-11-22 23:24:04,744 - INFO - Request URL: https://tl.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:04,904 - INFO - Found tl article: George Washington
# 2024-11-22 23:24:04,904 - INFO - Request URL: https://ja.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ジョージ・ワシントン&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:05,170 - INFO - Found ja article: ジョージ・ワシントン
# 2024-11-22 23:24:05,170 - INFO - Request URL: https://si.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ජෝර්ජ් වොෂිංටන්&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:05,307 - INFO - Found si article: ජෝර්ජ් වොෂිංටන්
# 2024-11-22 23:24:05,307 - INFO - Request URL: https://bn.wikipedia.org/w/api.php?action=query&prop=extracts&titles=জর্জ ওয়াশিংটন&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:05,581 - INFO - Found bn article: জর্জ ওয়াশিংটন
# 2024-11-22 23:24:05,581 - INFO - Request URL: https://hi.wikipedia.org/w/api.php?action=query&prop=extracts&titles=जॉर्ज वॉशिंगटन&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:05,725 - INFO - Found hi article: जॉर्ज वॉशिंगटन
# 2024-11-22 23:24:05,725 - INFO - Request URL: https://ms.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:05,870 - INFO - Found ms article: George Washington
# 2024-11-22 23:24:05,870 - INFO - Request URL: https://he.wikipedia.org/w/api.php?action=query&prop=extracts&titles=ג'ורג' וושינגטון&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:06,215 - INFO - Found he article: ג'ורג' וושינגטון
# 2024-11-22 23:24:06,215 - INFO - Request URL: https://tr.wikipedia.org/w/api.php?action=query&prop=extracts&titles=George Washington&explaintext=1&exsectionformat=wiki
# 2024-11-22 23:24:06,399 - INFO - Found tr article: George Washington
# 2024-11-22 23:24:06,399 - INFO - Analyzing text for language: en
# 2024-11-22 23:24:34,549 - INFO - Analyzing text for language: pl
# 2024-11-22 23:24:39,911 - INFO - Analyzing text for language: it
# 2024-11-22 23:24:53,830 - INFO - Analyzing text for language: hu
# 2024-11-22 23:25:16,909 - INFO - Analyzing text for language: de
# 2024-11-22 23:25:35,326 - INFO - Analyzing text for language: nl
# 2024-11-22 23:25:39,261 - INFO - Analyzing text for language: el
# 2024-11-22 23:25:45,518 - INFO - Analyzing text for language: sv
# 2024-11-22 23:25:48,564 - INFO - Analyzing text for language: ko
# 2024-11-22 23:25:53,576 - INFO - Analyzing text for language: th
# 2024-11-22 23:26:09,742 - INFO - Analyzing text for language: tl
# 2024-11-22 23:26:10,387 - INFO - Analyzing text for language: ja
# 2024-11-22 23:26:22,809 - INFO - Analyzing text for language: si
# 2024-11-22 23:26:23,089 - INFO - Analyzing text for language: bn
# 2024-11-22 23:26:29,969 - INFO - Analyzing text for language: hi
# 2024-11-22 23:26:30,393 - INFO - Analyzing text for language: ms
# 2024-11-22 23:26:31,506 - INFO - Analyzing text for language: he
# 2024-11-22 23:26:52,367 - INFO - Analyzing text for language: tr
# 2024-11-22 23:26:57,971 - INFO - Analysis completed successfully
#          Article_Title Language Mean_Similarity Median_Similarity  \
# 0         Donald Trump       en           0.694             0.696
# 1         Donald Trump       pl           0.563             0.563
# 2         Donald Trump       it           0.629             0.634
# 3         Donald Trump       hu           0.696             0.704
# 4         Donald Trump       de            0.63             0.632
# ..                 ...      ...             ...               ...
# 805  George Washington       bn           0.645             0.643
# 806  George Washington       hi           0.615             0.587
# 807  George Washington       ms           0.595             0.614
# 808  George Washington       he           0.669             0.675
# 809  George Washington       tr           0.542             0.540
#
#     Standard_Deviation
# 0                0.063
# 1                 0.08
# 2                0.079
# 3                0.068
# 4                0.066
# ..                 ...
# 805              0.081
# 806              0.042
# 807              0.134
# 808              0.074
# 809              0.093
#
# [810 rows x 5 columns]
